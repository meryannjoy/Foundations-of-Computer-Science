# %% [markdown]
# # 2025-26 Project - Foundations of Computer Science

# %% [markdown]
# **Project by:**
# - Herandez, Nicole Winy </br>
# - Ortega, Azriel Matthew </br>
# - Tibayan, Meryann Joy

# %%
# import libraries
import pandas as pd
import os
import json

# %% [markdown]
# ### 1. Create a single dataframe with the concatenation of all input csv files, adding a column called country

# %%
# read csv files with read_csv function from pandas
videos_folder = "videos"

df_cavideos = pd.read_csv(f"{videos_folder}/CAvideos.csv")
df_devideos = pd.read_csv(f"{videos_folder}/DEvideos.csv")
df_frvideos = pd.read_csv(f"{videos_folder}/FRvideos.csv")
df_gbvideos = pd.read_csv(f"{videos_folder}/GBvideos.csv")
df_invideos = pd.read_csv(f"{videos_folder}/INvideos.csv")
df_usvideos = pd.read_csv(f"{videos_folder}/USvideos.csv")

# After experimenting, it seems that using default encoding(utf-8) and using encoding errors
# to skip some bytes that cant be read is better than finding a specific encoding for each language
# However, this must be researched more for example: If this only a computer specific problem, or 
# there is a way to read everything properly without having to use encoding errors

df_jpvideos = pd.read_csv(f"{videos_folder}/JPvideos.csv", encoding="utf-8", encoding_errors="replace", engine="python")
df_krvideos = pd.read_csv(f"{videos_folder}/KRvideos.csv", encoding="utf-8", encoding_errors="replace", engine="python")
df_mxvideos = pd.read_csv(f"{videos_folder}/MXvideos.csv", encoding="utf-8", encoding_errors="replace", engine="python")
df_ruvideos = pd.read_csv(f"{videos_folder}/RUvideos.csv", encoding="utf-8", encoding_errors="replace", engine="python")

# %% [markdown]
# They say it is hard to determine the correct encoding for each text file, especially if it is not utf-8 </br>
# Reference https://community.dataquest.io/t/how-do-we-know-the-encoding-to-use-with-pd-read-csv-chardet-doesnt-help/467614/4 </br>
#
# You have to do trial and error with all of the encodings to check which one works best. As for my testing 11/20/2025, utf-8 is best for all with the encoding_errors set to replace.
#
# Here is the docs for checking all encodings : https://docs.python.org/3/library/codecs.html#standard-encodings

# %%
# Efficient code version (with concatenation process

# Import all csv files, read and compile them into one dataframe
# With the addition of adding a new column 'country' to determine from what csv file it came from

dataframe_lists = []
for file in os.listdir(videos_folder):
    if file[9:] == "csv":
        print(f"Reading {file}")
        df_temp = pd.read_csv(f"{videos_folder}/{file}", encoding_errors="replace")
        df_temp["country"] = file[:2] # add country column
        dataframe_lists.append(df_temp)

df_videos = pd.concat(dataframe_lists) # concatenate everything into one dataframe
df_videos = df_videos.reset_index(drop=True) # reset index
# Out:
# Reading MXvideos.csv
# Reading DEvideos.csv
# Reading FRvideos.csv
# Reading INvideos.csv
# Reading RUvideos.csv
# Reading JPvideos.csv
# Reading GBvideos.csv
# Reading KRvideos.csv
# Reading CAvideos.csv
# Reading USvideos.csv

# %%
df_videos
# Out:
#            video_id trending_date  \
# 0       SbOwzAl9ZfQ      17.14.11
# 1       klOV6Xh-DnI      17.14.11
# 2       6L2ZF7Qzsbk      17.14.11
# 3       hcY52MFWMDM      17.14.11
# 4       _OXDcGPVAa4      17.14.11
# ...             ...           ...
# 375937  BZt0qjTWNhw      18.14.06
# 375938  1h7KV2sjUWY      18.14.06
# 375939  D6Oy4LfoqsU      18.14.06
# 375940  oV0zkMe1K8s      18.14.06
# 375941  ooyjaVdt-jA      18.14.06
#
#                                                     title  \
# 0                           Capítulo 12 | MasterChef 2017
# 1       ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2                  LOUIS CKAGÓ - EL PULSO DE LA REPÚBLICA
# 3        Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4                DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                   ...
# 375937                       The Cat Who Caught the Laser
# 375938                         True Facts : Ant Mutualism
# 375939  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 375940                How Black Panther Should Have Ended
# 375941  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  category_id              publish_time  \
# 0                MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1       Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2       El Pulso De La República           25  2017-11-13T17:00:02.000Z
# 3                       Casanare           25  2017-11-13T03:47:10.000Z
# 4                          Musas           26  2017-11-13T19:17:48.000Z
# ...                          ...          ...                       ...
# 375937             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 375938                  zefrank1           22  2018-05-18T01:00:06.000Z
# 375939                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 375940  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 375941              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                      tags     views   likes  \
# 0       MasterChef Junior 2017|"TV Azteca"|"recetas"|"...    310130    4182
# 1                                         La Voz Mexico 7    104972     271
# 2       Chumel Torres|"El Pulso de la Republica"|"noti...    136064   10105
# 3              temblor|"costa rica"|"sismo en costa rica"     96153     378
# 4       MUSAS|"lesslie"|"karen"|"hacks"|"perros"|"dogs...    499965   57781
# ...                                                   ...       ...     ...
# 375937  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 375938                                             [none]   1064798   60008
# 375939  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 375940  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 375941      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#         dislikes  comment_count  \
# 0            361           1836
# 1            174            369
# 2            266            607
# 3            171            208
# 4            681           7428
# ...          ...            ...
# 375937      1385           2657
# 375938       382           3936
# 375939      1032           3992
# 375940      2846          13088
# 375941    212976         144795
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/SbOwzAl9ZfQ/default.jpg              False
# 1       https://i.ytimg.com/vi/klOV6Xh-DnI/default.jpg              False
# 2       https://i.ytimg.com/vi/6L2ZF7Qzsbk/default.jpg              False
# 3       https://i.ytimg.com/vi/hcY52MFWMDM/default.jpg              False
# 4       https://i.ytimg.com/vi/_OXDcGPVAa4/default.jpg              False
# ...                                                ...                ...
# 375937  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 375938  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 375939  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 375940  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 375941  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 375937             False                   False
# 375938             False                   False
# 375939             False                   False
# 375940             False                   False
# 375941             False                   False
#
#                                               description country
# 0       Disfruta la presencia del Chef Torreblanca en ...      MX
# 1       ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...      MX
# 2       La canción del principio se llama “Este espíri...      MX
# 3       El video es de un Walmart en el pais centroame...      MX
# 4       MI HERMANO NARRA MI RUTINA DE MAQUILLAJE\nhttp...      MX
# ...                                                   ...     ...
# 375937     The Cat Who Caught the Laser - Aaron's Animals      US
# 375938                                                NaN      US
# 375939  I had so much fun transforming Safiyas hair in...      US
# 375940  How Black Panther Should Have EndedWatch More ...      US
# 375941  Call of Duty: Black Ops 4 Multiplayer raises t...      US
#
# [375942 rows x 17 columns]

# %% [markdown]
# ### 2. Extract all videos that have no tag.

# %%
no_tag_videos = df_videos[df_videos["tags"] == "[none]"]
no_tag_videos #all videos
# Out:
#            video_id trending_date  \
# 5       Q9kK6NWZR1U      17.14.11
# 19      7D-swI6qNLM      17.14.11
# 25      nEAMm3nGxpM      17.14.11
# 38      cgYhR-3QfhM      17.14.11
# 56      mevdRfjbwH4      17.14.11
# ...             ...           ...
# 375815  VGykknw9eCM      18.14.06
# 375819  fAIX12F6958      18.14.06
# 375865  gS1DbvHHVH0      18.14.06
# 375873  E4c7EE8_IX0      18.14.06
# 375938  1h7KV2sjUWY      18.14.06
https://i.ytimg.com/vi/VGykknw9eCM/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 5                  False                   False
# 19                 False                   False
# 25                 False                   False
# 38                 False                   False
# 56                 False                   False
# ...                  ...                     ...
# 367560             False                   False
# 367812             False                   False
# 368782             False                   False
# 368876             False                   False
# 374773             False                   False
#
#                                               description country
# 5       Un fuerte sismo ha afectado en la noche de est...      MX
# 19      CANAL DE HISTORIAS:\nhttps://www.youtube.com/H...      MX
# 25      A lo largo de su vida, Alejo Garza Tamez ha cu...      MX
# 38              NOTICIAS DE HOY NUEVAS 13 DE OCTUBRE 2017      MX
# 56                                                    NaN      MX
# ...                                                   ...     ...
# 367560  CONAN Highlight: The people of Delaware think ...      US
# 367812  For licensing/usage please contact: licensing(...      US
# 368782  For tickets & tour info head to: http://www.sh...      US
# 368876  hey guys! i know this is a lil different than ...      US
# 374773  When your time comes, you have two choices. Yo...      US
#
# [23992 rows x 17 columns]

# %% [markdown]
# ### 3. For each channel, determine the total number of views

# %%
total_views_per_channel = df_videos.groupby("channel_title")["views"].sum().sort_values(ascending=False)
total_views_per_channel
# Out:
# channel_title
# ChildishGambinoVEVO     11016766510
# Marvel Entertainment    10430605449
# NickyJamTV               9479859505
# Ozuna                    8623329509
# ibighit                  8205572221
#                            ...
# NavylittleMonster               365
# Videostendencias                302
# No Comment TV                   284
# Sport Life                      163
# Alexander Redking               153
# Name: views, Length: 37824, dtype: int64

# %% [markdown]
# ### 4. Save all rows with disabled comments and disabled ratings, or that have video_error_or_removed in a new dataframe called excluded, and remove those rows from the original dataframe.

# %%
df_videos_disabled = df_videos[df_videos["comments_disabled"] | df_videos["ratings_disabled"] | df_videos["video_error_or_removed"]]
df_videos_disabled
# Out:
#            video_id trending_date  \
# 7       XzULSsZYMRc      17.14.11
# 14      Dhhp8M5K3UI      17.14.11
# 32      RkTi5_hu-kY      17.14.11
# 88      qxyJYWGf57k      17.14.11
# 89      P3q93hzUGEA      17.14.11
# ...             ...           ...
# 375542  FchkqXEg0qs      18.13.06
# 375617  J2m7EUwnqGg      18.13.06
# 375624  lBbSzQXQknw      18.13.06
# 375825  J2m7EUwnqGg      18.14.06
# 375832  lBbSzQXQknw      18.14.06
#
#                                                     title  \
# 7       M6.7 Costa Rica Análisis de Terremotos en (((A...
# 14                                          Deleted video
# 32      YURI puso en su lugar a EX TIMBIRICHE en La Vo...
# 88      Santa Misa del lunes 13 de noviembre de 2017 (...
# 89      Fraudulenta salida de Lis Vega en el Exatlon M...
# ...                                                   ...
# 375542                          Nintendo @ E3 2018: Day 1
# 375617            iPhone X — Animoji: Taxi Driver — Apple
# 375624  And the WINNER of Britain’s Got Talent 2018 is...
# 375825            iPhone X — Animoji: Taxi Driver — Apple
# 375832  And the WINNER of Britain’s Got Talent 2018 is...
#
#                channel_title  category_id              publish_time  \
# 7            concienciaradio           25  2017-11-13T06:18:23.000Z
# 14                  Harrison           24  2017-11-13T04:44:51.000Z
# 89      Salida de Lis Vega del Exatlon México 2017 cau...      MX
# ...                                                   ...     ...
# 375542  ESRB Rating: RATING PENDING to Teen. Rating Pe...      US
# 375617  Animoji on iPhone X (feat. HYUKOH) Learn more ...      US
# 375624  What an amazing show our acts put on tonight f...      US
# 375825  Animoji on iPhone X (feat. HYUKOH) Learn more ...      US
# 375832  What an amazing show our acts put on tonight f...      US
#
# [13657 rows x 17 columns]

# %%
df_videos = df_videos.drop(df_videos_disabled.index)
df_videos
# Out:
#            video_id trending_date  \
# 0       SbOwzAl9ZfQ      17.14.11
# 1       klOV6Xh-DnI      17.14.11
# 2       6L2ZF7Qzsbk      17.14.11
# 3       hcY52MFWMDM      17.14.11
# 4       _OXDcGPVAa4      17.14.11
# ...             ...           ...
# 375937  BZt0qjTWNhw      18.14.06
# 375938  1h7KV2sjUWY      18.14.06
# 375939  D6Oy4LfoqsU      18.14.06
# 375940  oV0zkMe1K8s      18.14.06
# 375941  ooyjaVdt-jA      18.14.06
#
#                                                     title  \
# 0                           Capítulo 12 | MasterChef 2017
# 1       ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2                  LOUIS CKAGÓ - EL PULSO DE LA REPÚBLICA
# 3        Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4                DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                   ...
# 375937                       The Cat Who Caught the Laser
# 375938                         True Facts : Ant Mutualism
# 375939  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 375940                How Black Panther Should Have Ended
# 375941  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  category_id              publish_time  \
# 0                MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1       Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2       El Pulso De La República           25  2017-11-13T17:00:02.000Z
# 3                       Casanare           25  2017-11-13T03:47:10.000Z
# 4                          Musas           26  2017-11-13T19:17:48.000Z
# ...                          ...          ...                       ...
# 375937             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 375938                  zefrank1           22  2018-05-18T01:00:06.000Z
# 375939                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 375940  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 375941              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                      tags     views   likes  \
# 0       MasterChef Junior 2017|"TV Azteca"|"recetas"|"...    310130    4182
# 1                                         La Voz Mexico 7    104972     271
# 2       Chumel Torres|"El Pulso de la Republica"|"noti...    136064   10105
# 3              temblor|"costa rica"|"sismo en costa rica"     96153     378
# 4       MUSAS|"lesslie"|"karen"|"hacks"|"perros"|"dogs...    499965   57781
# ...                                                   ...       ...     ...
# 375937  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 375938                                             [none]   1064798   60008
# 375939  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 375940  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 375941      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#         dislikes  comment_count  \
# 0            361           1836
# 1            174            369
# 2            266            607
# 3            171            208
# 4            681           7428
# ...          ...            ...
# 375937      1385           2657
# 375938       382           3936
# 375939      1032           3992
# 375940      2846          13088
# 375941    212976         144795
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/SbOwzAl9ZfQ/default.jpg              False
# 1       https://i.ytimg.com/vi/klOV6Xh-DnI/default.jpg              False
# 2       https://i.ytimg.com/vi/6L2ZF7Qzsbk/default.jpg              False
# 3       https://i.ytimg.com/vi/hcY52MFWMDM/default.jpg              False
# 4       https://i.ytimg.com/vi/_OXDcGPVAa4/default.jpg              False
# ...                                                ...                ...
# 375937  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 375938  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 375939  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 375940  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 375941  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 375937             False                   False
# 375938             False                   False
# 375939             False                   False
# 375940             False                   False
# 375941             False                   False
#
#                                               description country
# 0       Disfruta la presencia del Chef Torreblanca en ...      MX
# 1       ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...      MX
# 2       La canción del principio se llama “Este espíri...      MX
# 3       El video es de un Walmart en el pais centroame...      MX
# 4       MI HERMANO NARRA MI RUTINA DE MAQUILLAJE\nhttp...      MX
# ...                                                   ...     ...
# 375937     The Cat Who Caught the Laser - Aaron's Animals      US
# 375938                                                NaN      US
# 375939  I had so much fun transforming Safiyas hair in...      US
# 375940  How Black Panther Should Have EndedWatch More ...      US
# 375941  Call of Duty: Black Ops 4 Multiplayer raises t...      US
#
# [362285 rows x 17 columns]

# %% [markdown]
# ### 5. Add a like_ratio column storing the ratio between the number of likes and of dislikes

# %%
import numpy as np
df_videos["like_ratio"] = df_videos["likes"] / df_videos["dislikes"].replace(0, np.nan)
df_videos[["title", "likes", "dislikes", "like_ratio"]].head(10)
# Out:
#                                                 title  likes  dislikes  \
# 0                       Capítulo 12 | MasterChef 2017   4182       361
# 1   ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...    271       174
# 2              LOUIS CKAGÓ - EL PULSO DE LA REPÚBLICA  10105       266
# 3    Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017    378       171
# 4            DOG HACKS | MUSAS LESSLIE LOS POLINESIOS  57781       681
# 5   Asi se sintio Terremoto en iraq al bordo de ir...    506        67
# 6   La Resolana con el Capi | Programa 12 noviembr...   2277        69
# 8   7 Niños Famosos Que No Supieron Adaptarse a La...  20155       912
# 9   TOP: Los 7 libros infantiles más perturbadores...  83582      2194
# 10         Franco Escamilla.- Tradiciones y Faitelson  23279       270
#
#     like_ratio
# 0    11.584488
# 1     1.557471
# 2    37.988722
# 3     2.210526
# 4    84.847283
# 5     7.552239
# 6    33.000000
# 8    22.099781
# 9    38.095716
# 10   86.218519

# %%
# if needed: how many rows have like_ratio = NaN
num_nan_ratio = df_videos["like_ratio"].isna().sum()
print("Righe con like_ratio NaN:", num_nan_ratio)

# rows with like_ratio NaN
ratio_nan_rows = df_videos[df_videos["like_ratio"].isna()]
ratio_nan_rows.head(5)
# Out:
# Righe con like_ratio NaN: 2390
#         video_id trending_date  \
# 120  vl8yv7kTTWI      17.14.11
# 188  MGeSKdq1V20      17.14.11
# 194  _0FiEmKkIHU      17.14.11
# 303  AWqYXzvT4OM      17.15.11
# 384  dqMGDmIIusg      17.15.11
#
#                                                  title  \
# 120            Budín de zanahoria - Cocina Vegan Fácil
# 188  Iraqi Kurdistan Earthquake live during an inte...
# 194             TERREMOTO 6.5 EN COSTA RICA 12/11/2017
# 303  Transmisión en vivo del LXXIII Congreso y Camp...
# 384  Caer en tentación: Mía descubre la verdad | Es...
#
#                               channel_title  category_id  \
# 120                      Cocina Vegan fácil           24
# 188                          Ahmed Nasradin           22
# 194                            ElJuanjoSabe           25
# 303  Federación Mexicana de Charrería, A.C.           17
# 384                           Las Estrellas           24
#
#                  publish_time  \
# 120  2017-11-13T14:00:03.000Z
# 188  2017-11-12T19:44:05.000Z
# 194  2017-11-13T05:25:05.000Z
# 303  2017-11-14T22:53:18.000Z
# 384  2017-11-15T04:30:00.000Z
#
#                                                   tags  views  likes  \
# 120  budín|"zanahoria"|"budín de zanahoria"|"budín ...   5113    823
# 188                                             [none]   3033     12
# 194  TERREMOTO|"TERREMOTO EN COSTA RICA"|"COSTA RIC...   6481     20
# 303  Charrería|"Charros"|"México"|"Hidalgo"|"Pachuc...   3874     17
# 384  Televisa|"Telenovela"|"Soap Opera"|"Las Estrel...   3147     55
#
#      dislikes  comment_count                                  thumbnail_link  \
# 120         0            190  https://i.ytimg.com/vi/vl8yv7kTTWI/default.jpg
# 188         0              0  https://i.ytimg.com/vi/MGeSKdq1V20/default.jpg
# 194         0              2  https://i.ytimg.com/vi/_0FiEmKkIHU/default.jpg
# 303         0              0  https://i.ytimg.com/vi/AWqYXzvT4OM/default.jpg
# 384         0             10  https://i.ytimg.com/vi/dqMGDmIIusg/default.jpg
#
#      comments_disabled  ratings_disabled  video_error_or_removed  \
# 120              False             False                   False
# 188              False             False                   False
# 194              False             False                   False
# 303              False             False                   False
# 384              False             False                   False
#
#                                            description country  like_ratio
# 120  Hoy tenemos un delicioso postre vegano, budín ...      MX         NaN
# 188  An Earthquake hit iraq with 7.2 Magnitude , st...      MX         NaN
# 194  n sismo de magnitud 6,5 ha sacudido este domin...      MX         NaN
# 303  En vivo desde el lienzo charro Hidalgo, Cuna d...      MX         NaN
# 384  Damian y Carolina son descubiertos por Mía. El...      MX         NaN

# %% [markdown]
# ### 6. Cluster the publish time into 10-minute intervals (e.g. from 02:20 to 02:30)

# %%
pt = pd.to_datetime(df_videos["publish_time"], utc=True, errors="coerce")
start = pt.dt.floor("10min")
df_videos["publish_interval"] = (
    start.dt.strftime("%H:%M") + " - " +
    (start + pd.Timedelta(minutes=10)).dt.strftime("%H:%M")
)

df_videos[["publish_time", "publish_interval"]]
# Out:
#                     publish_time publish_interval
# 0       2017-11-13T06:06:22.000Z    06:00 - 06:10
# 1       2017-11-13T05:11:58.000Z    05:10 - 05:20
# 2       2017-11-13T17:00:02.000Z    17:00 - 17:10
# 3       2017-11-13T03:47:10.000Z    03:40 - 03:50
# 4       2017-11-13T19:17:48.000Z    19:10 - 19:20
# ...                          ...              ...
# 375937  2018-05-18T13:00:04.000Z    13:00 - 13:10
# 375938  2018-05-18T01:00:06.000Z    01:00 - 01:10
# 375939  2018-05-18T17:34:22.000Z    17:30 - 17:40
# 375940  2018-05-17T17:00:04.000Z    17:00 - 17:10
# 375941  2018-05-17T17:09:38.000Z    17:00 - 17:10
#
# [362285 rows x 2 columns]

# %% [markdown]
# ### 7. For each interval, determine the number of videos, average number of likes and of dislikes.

# %%
# Unique Videos

interval_stats = df_videos.groupby("publish_interval").agg(
    number_of_videos = ("video_id", "nunique"),
    average_likes = ("likes", "mean"),
    average_dislikes = ("dislikes", "mean")
)

interval_stats.sort_index().head(50)
# Out:
#                   number_of_videos  average_likes  average_dislikes
# publish_interval
# 00:00 - 00:10                 1329   62819.249823       3902.800425
# 00:10 - 00:20                  717   20898.900281       1448.770365
# 00:20 - 00:30                  617   22120.714762       1109.575480
# 00:30 - 00:40                  807   38038.324342        981.208735
# %%
df_videos_tags_explode = df_videos_tags.explode('tags')

# %%
# clean dataset by removing all extra characters such as double quotations (")
df_videos_tags_explode["tags"] = df_videos_tags_explode["tags"].str.replace('"', '').str.strip()

# %%
df_videos_tags_explode = df_videos_tags_explode[df_videos_tags_explode['tags'].str.strip() != ""]

# %%
# Videos with no tags are excluded
df_videos_tags_explode.groupby(by="tags")['video_id'].nunique()
# Out:
# tags
# ! Banii i-au luat mintile                          2
# !!                                                 5
# !! *me bloquea*                                    1
# !!!                                                1
# !!!!                                               2
#                                                   ..
# 😜😜                                                 1
# 😥                                                  1
# 😭 #résistancelamaindesqueezie ❤️                   1
# 😭قفز عسكري الوحيد من الطائرة العسكرية الجزائرية    1
# 🤝 ZARBEX zahlt Schutzgeld!!!                       1
# Name: video_id, Length: 831130, dtype: int64

# %%
# Number of videos with no tags (if needed)
df_videos_tags_explode[df_videos_tags_explode["tags"] == "[none]"]["video_id"].nunique()
# Out:
# 22580

# %% [markdown]
# ### 9. Find the tags with the largest number of videos

# %%
df_videos_tags_explode[df_videos_tags_explode["tags"] != "[none]"].groupby(by="tags")['video_id'].nunique().sort_values(ascending=False).head(1)
# Out:
# tags
# 2018    5524
# Name: video_id, dtype: int64

# %% [markdown]
# ### 10. For each (tag, country) pair, compute average ratio likes/dislikes

# %%
df_videos_tags_only = df_videos_tags_explode[(df_videos_tags_explode["tags"] != "[none]")]

# %%
pd.DataFrame(df_videos_tags_only.groupby(by=["tags","country"])["like_ratio"].mean())
# Out:
#                                                          like_ratio
# tags                                            country
# ! Banii i-au luat mintile                       DE         6.222739
# !!                                              FR        12.452875
#                                                 MX        38.081559
# !! *me bloquea*                                 MX        65.260870
# !!!                                             MX        12.952381
# ...                                                             ...
# 😜😜                                              RU         7.203704
# 😥                                               DE        26.384615
# 😭 #résistancelamaindesqueezie ❤️                FR        10.219048
# 😭قفز عسكري الوحيد من الطائرة العسكرية الجزائرية FR         6.223873
# 🤝 ZARBEX zahlt Schutzgeld!!!                    DE        13.989691
#
# [1076212 rows x 1 columns]

# %% [markdown]
# ### 11. For each (trending_date, country) pair, the video with the largest number of views

# %%
max_views = df_videos.groupby(["trending_date", "country"])["views"].transform("max")
max_views
# Out:
# 0          4477587
# 1          4477587
# 2          4477587
# 3          4477587
# 4          4477587
#             ...
# 375937    94254507
# 375938    94254507
# 375939    94254507
# 375940    94254507
# 375941    94254507
# Name: views, Length: 362285, dtype: int64

# %%
max_views = df_videos.groupby(["trending_date", "country"])["views"].transform("max")
df_videos_group = df_videos[df_videos["views"] == max_views]

# %%
# Sort columns, to display Country, Trending Date and then Views First.
priority_columns = ["trending_date","country", "views"]
other_columns = [col for col in df_videos.columns if col not in priority_columns]

df_videos_group[priority_columns + other_columns]
# Out:
#        trending_date country     views     video_id  \
# 177         17.14.11      MX   4477587  JzCsM1vtn78
# 267         17.15.11      MX   2765121  VsYmwBOYfW8
# 618     After surviving a near fatal bovine attack, a ...   49.562445
# 812     “Échame La Culpa” disponible ya en todas las p...   31.154967
# ...                                                   ...         ...
# 375036  Cardi B, Bad Bunny & J Balvin - I Like It from...   17.894576
# 375237  Cardi B, Bad Bunny & J Balvin - I Like It from...   17.887485
# 375451  Cardi B, Bad Bunny & J Balvin - I Like It from...   17.847340
# 375655  Cardi B, Bad Bunny & J Balvin - I Like It from...   17.783779
# 375862  Cardi B, Bad Bunny & J Balvin - I Like It from...   17.728917
#
#        publish_interval
# 177       20:10 - 20:20
# 267       08:30 - 08:40
# 402       14:00 - 14:10
# 618       14:00 - 14:10
# 812       05:00 - 05:10
# ...                 ...
# 375036    14:00 - 14:10
# 375237    14:00 - 14:10
# 375451    14:00 - 14:10
# 375655    14:00 - 14:10
# 375862    14:00 - 14:10
#
# [2126 rows x 19 columns]

# %% [markdown]
# ### 12. Divide trending_date into three columns: year, month, day

# %%
# Split the 'trending_date' column
# The expand=True parameter turns the result into a DataFrame
data_split = df_videos['trending_date'].str.split('.', expand=True)

# Assign New Columns
# Index 0 = Year (YY) -> add '20' to get '2017'
df_videos['year'] = '20' + data_split[0].astype(str)
# Index 1 = Day (DD)
df_videos['day'] = data_split[1]
# Index 2 = Month (MM)
df_videos['month'] = data_split[2]

print(df_videos[['video_id','trending_date', 'year', 'month', 'day']].head())
# Out:
#       video_id trending_date  year month day
# 0  SbOwzAl9ZfQ      17.14.11  2017    11  14
# 1  klOV6Xh-DnI      17.14.11  2017    11  14
# 2  6L2ZF7Qzsbk      17.14.11  2017    11  14
# 3  hcY52MFWMDM      17.14.11  2017    11  14
# 4  _OXDcGPVAa4      17.14.11  2017    11  14

# %%
# Convert to datetime format
# Use format YYYY-MM-DD
df_videos['trending_date'] = pd.to_datetime(df_videos['trending_date'], format='%y.%d.%m')

# Extract the components
df_videos['year'] = df_videos['trending_date'].dt.year
df_videos['month'] = df_videos['trending_date'].dt.month
df_videos['day'] = df_videos['trending_date'].dt.day

print(df_videos[['trending_date', 'year', 'month', 'day']].head())
# Out:
#   trending_date  year  month  day
# 0    2017-11-14  2017     11   14
# 1    2017-11-14  2017     11   14
# 2    2017-11-14  2017     11   14
# 3    2017-11-14  2017     11   14
# 4    2017-11-14  2017     11   14

# %% [markdown]
# ### 13. For each (month, country) pair, the video with the largest number of views

# %%
# Group by 'month' and 'country'
# Find the index of the row with the highest 'views' value in each group
max_views_indices = df_videos.groupby(['month', 'country'])['views'].idxmax()

# 3. Use .loc to select the rows from the original DataFrame
df_max_views = df_videos.loc[max_views_indices]

print(df_max_views[['month', 'country', 'video_id','title', 'views']].head())
# Out:
#         month country     video_id  \
# 305326      1      CA  LsoLEjrDogU
# 51500       1      DE  LsoLEjrDogU
# 92423       1      FR  LsoLEjrDogU
# 233392      1      GB  LsoLEjrDogU
# 134059      1      IN  dfnCAmr569k
#
#                                                     title     views
# 305326  Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...  43067983
# 51500   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...  37728802
# 92423   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...  37728802
# 233392  Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...  90598955
# 134059     Taylor Swift - End Game ft. Ed Sheeran, Future  42019590

# %% [markdown]
# ### 14. Read all json files with the video categories

# %%
json_folder = 'categories'
df_list = []

for file in os.listdir(json_folder):
    if file.endswith(".json"):
        print(f"Reading {file}")
        
        with open(os.path.join(json_folder, file), 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # Correct normalization for YouTube categories
        df_temp = pd.json_normalize(data['items'])
        
        # Select only the useful columns
        df_temp = df_temp[['id', 'snippet.title', 'snippet.assignable']]
        
        # Rename for consistency with the video dataframe
        df_temp.columns = ['category_id', 'category_name', 'assignable']
        
        # Convert category_id to integer
        df_temp['category_id'] = df_temp['category_id'].astype(int)
        
        df_list.append(df_temp)

df_categories = pd.concat(df_list, ignore_index=True)
df_categories = df_categories.drop_duplicates(subset=['category_id']).reset_index(drop=True)

df_categories
# Out:
# Reading FR_category_id.json
# Reading CA_category_id.json
# Reading US_category_id.json
# Reading JP_category_id.json
# Reading GB_category_id.json
# Reading MX_category_id.json
# Reading RU_category_id.json
# Reading IN_category_id.json
# Reading KR_category_id.json
# Reading DE_category_id.json
#     category_id          category_name  assignable
# 0             1       Film & Animation        True
# 1             2       Autos & Vehicles        True
# 2            10                  Music        True
# 3            15         Pets & Animals        True
# 4            17                 Sports        True
# 5            18           Short Movies       False
# 6            19        Travel & Events        True
# 7            20                 Gaming        True
# 8            21          Videoblogging       False
# 9            22         People & Blogs        True
# 10           23                 Comedy        True
# 11           24          Entertainment        True
# 12           25        News & Politics        True
# 13           26          Howto & Style        True
# 14           27              Education        True
# 15           28   Science & Technology        True
# 16           30                 Movies       False
# 17           31        Anime/Animation       False
# 18           32       Action/Adventure       False
# 19           33               Classics       False
# 20           34                 Comedy       False
# 21           35            Documentary       False
# 22           36                  Drama       False
# 23           37                 Family       False
# 24           38                Foreign       False
# 25           39                 Horror       False
# 26           40         Sci-Fi/Fantasy       False
# 27           41               Thriller       False
# 28           42                 Shorts       False
# 29           43                  Shows       False
# 30           44               Trailers       False
# 31           29  Nonprofits & Activism        True

# %% [markdown]
# ### 15. For each country, determine how many videos have a category that is not assignable

# %%
df_merged = df_videos.merge(df_categories, on='category_id', how='left')

# %%
df_not_assignable = (df_merged[df_merged['assignable'] == False]
    .groupby('country')['video_id']
    .count()
    .reset_index(name='non_assignable_count')
)

# this counts number of rows that are not assignable
df_not_assignable
# Out:
#   country  non_assignable_count
# 0      CA                   130
# 1      DE                   102
# 2      FR                   110
# 3      GB                    20
# 4      IN                   220
# 5      KR                   167
# 6      MX                     3
# 7      RU                   183
# 8      US                    57

# %%
# this counts number of unique videos that are not assignable
df_not_assignable_unique = (df_merged[df_merged['assignable'] == False]
    .groupby('country')['video_id']
    .nunique()
    .reset_index(name='non_assignable_count')
)

df_not_assignable_unique
# Out:
#   country  non_assignable_count
# 0      CA                   111
# 1      DE                    97
# 2      FR                   106
# 3      GB                     1
# 4      IN                   123
# 5      KR                    75
# 6      MX                     3
# 7      RU                   158
# 8      US                     4
